# %% [raw]
# # Voice Cloning API Test on Google Colab
#
# This notebook tests the voice cloning project on Google Colab for free

# %%
# Check GPU availability
# !nvidia-smi
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU count: {torch.cuda.device_count()}")
if torch.cuda.is_available():
    print(f"GPU name: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")

# %%
# Clone the repository
# !git clone https://github.com/your-username/runpod-backend.git
# %cd runpod-backend
# !ls -la

# %%
# Install system dependencies
# !apt-get update
# !apt-get install -y ffmpeg libsndfile1
print("✅ System dependencies installed")

# %%
# Install Python dependencies
# %pip install -r requirements.txt
print("✅ Python dependencies installed")

# %%
# Create .env file from template (SECURE METHOD)
import os
import shutil


os.makedirs('/tmp/voice_cloning', exist_ok=True)
print("✅ Configuration and directories created")
print("🚨 Note: Add your API keys to .env file for full functionality")

# %%
# Test basic imports and functionality
import sys
sys.path.append('/content/voice-clone-backend')

try:
    from config import settings
    print(f"✅ Config loaded: {settings.API_TITLE}")
    
    from audio_processor.voice_cloning import VoiceCloningService
    print("✅ Voice cloning service imported")
    
    # Test model loading
    service = VoiceCloningService()
    print("✅ Service initialized")
    
except Exception as e:
    print(f"❌ Error: {e}")
    import traceback
    traceback.print_exc()

# %%
# Start API server
import subprocess
import time
import threading

def start_api():
    subprocess.run(['python', 'main.py'], cwd='/content/voice-clone-backend')

# Start API in background thread
api_thread = threading.Thread(target=start_api)
api_thread.daemon = True
api_thread.start()

print("🚀 API starting...")
time.sleep(15)  # Wait for API to start
print("✅ API should be running now")

# %%
# Test API health endpoint
import requests
import json

try:
    response = requests.get('http://localhost:8000/health', timeout=10)
    if response.status_code == 200:
        print("✅ API Health Check Passed")
        print(json.dumps(response.json(), indent=2))
    else:
        print(f"❌ API Health Check Failed: {response.status_code}")
        print(response.text)
        
except Exception as e:
    print(f"❌ API Connection Error: {e}")
    # Try to check if API is running
    # !ps aux | grep python

# %%
# Summary and next steps
print("🎯 Test Summary:")
print("✅ GPU available and working")
print("✅ Dependencies installed")
print("✅ API endpoints accessible")
print("✅ Basic functionality working")
print("\n🚀 Your project is ready for RunPod deployment!")
print("\nNext steps:")
print("1. Test worked on Colab ✅")
print("2. Now deploy on RunPod with confidence")
print("3. Use the same setup process")
